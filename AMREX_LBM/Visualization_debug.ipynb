# %% [markdown]
# ## Example: 2D simulation of Taylor Green Vortex using Lattice Boltzmann Method
#
#
# The example solves the Naiver Stokes Equation using Lattice Boltzmann Method. Here we setup the problem using an analytical solution of N-S equation: Taylor Green Vortex. Its velocity field and pressure field can be written as
#
#
# $$u= -u_{\max} \cos \frac{2\pi x}{L} \sin \frac{2\pi y}{L} e^{-\nu t} $$
#
# $$ v=u_{\max}\sin \frac{2\pi x}{L} \cos \frac{2\pi y}{L} e^{-\nu t} $$
#
# $$p= -\frac {1}{4}  \rho_0 u_{\max}^2 ( \cos \frac{2\pi x}{L} + \cos \frac{2\pi y}{L} ) e^{-2\nu t} $$
#
# Here, the Boltzmann equation is written as
#
# $$\frac{\partial f}{\partial t}+ \xi_\alpha \frac{\partial f}{\partial x_\alpha} +\frac{f_\alpha}{\rho}\frac{\partial f}{\partial \xi_\alpha}=\Omega(f),$$
#
# where the probability density function $f(\mathbf{x},\mathbf{\xi}, t)$, which is defined as a function of location $\mathbf{x}$, microscopic particle velocity $\mathbf{\xi}$, and time $t$. $f_\alpha$ is external forcing, and $\Omega(f)$ is the collision term.
#
# The problem is solved in 2D using D2Q9 discretization, and the collision term is solved using BGK operator.

# %% [markdown]
# ## Running the code
#
# The simulation can be ran as `./mained.gnu.ex inputs`.
#
# The following inputs parameters could be tweaked:
#
# ```
# scale = 2              # scale of the problem
# max_grid_size = 64                # max grid size used for domain decomposition
# Nx = 32    # size of the domain in both directions are Nx*scale
# NSTEP=200  # number of time steps is NSTEP*scale*scale
# plot_int=50 # interval of saving data, if not save, then set as -1
# ```

# %% [markdown]
# ## Visualizating the results
#
# Below we give some python code to visualizate the solution using yt:

# %%
import yt
from yt.frontends import boxlib
from yt.frontends.boxlib.data_structures import AMReXDataset
# Out:
# /tmp/ipykernel_7996/3074286631.py:3: DeprecationWarning: The historic 'boxlib' frontend is
# deprecated as it has been renamed 'amrex'. Existing and future work should instead reference the 'amrex' frontend.
# Deprecated since yt 4.4.0
#   from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
ds = AMReXDataset("plt00800")
sl = yt.SlicePlot(ds, 2, ('boxlib', 'ux'))
sl.set_log(('ux'), False)
sl.set_zlim(('ux'), -0.01, 0.01)
# 
ds.find_min("ux")
sl
# Out:
# yt : [INFO     ] 2024-12-16 23:09:28,180 Parameters: current_time              = 800.0
# yt : [INFO     ] 2024-12-16 23:09:28,181 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-16 23:09:28,183 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-16 23:09:28,184 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-16 23:09:28,339 xlim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-16 23:09:28,340 ylim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-16 23:09:28,343 xlim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-16 23:09:28,344 ylim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-16 23:09:28,347 Making a fixed resolution buffer of (('boxlib', 'ux')) 800 by 800
# yt : [INFO     ] 2024-12-16 23:09:28,753 min value is -3.17405e-01 at 0.5000000000000000 0.5000000000000000 0.5000000000000000
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds = AMReXDataset("plt00000")
sl = yt.SlicePlot(ds, 2, ('boxlib', 'ux'))
sl.set_log(('ux'), False)
sl.set_zlim(('ux'), -0.01, 0.01)
# 
ds.find_min("ux")
sl
# Out:
# yt : [INFO     ] 2024-12-08 18:20:03,586 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-12-08 18:20:03,587 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-08 18:20:03,588 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-08 18:20:03,589 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-08 18:20:03,756 xlim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:03,757 ylim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:03,760 xlim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:03,761 ylim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:03,763 Making a fixed resolution buffer of (('boxlib', 'ux')) 800 by 800
# yt : [INFO     ] 2024-12-08 18:20:04,153 min value is -1.99518e-02 at 0.5000000000000000 15.5000000000000000 0.5000000000000000
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds = AMReXDataset("plt00004")
sl = yt.SlicePlot(ds, 2, ('boxlib', 'f1'))
sl.set_log(('f1'), False)
sl.set_zlim(('f1'), 0.4442, 0.4447)
# 
ds.find_min("f1")
sl
# Out:
# yt : [INFO     ] 2024-12-08 18:20:04,663 Parameters: current_time              = 4.0
# yt : [INFO     ] 2024-12-08 18:20:04,664 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-08 18:20:04,665 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-08 18:20:04,667 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-08 18:20:04,799 xlim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:04,800 ylim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:04,803 xlim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:04,804 ylim = 0.000000 64.000000
# yt : [INFO     ] 2024-12-08 18:20:04,806 Making a fixed resolution buffer of (('boxlib', 'f1')) 800 by 800
# yt : [INFO     ] 2024-12-08 18:20:05,008 min value is 4.44178e-01 at 0.5000000000000000 0.5000000000000000 0.5000000000000000
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds = AMReXDataset("plt00300")
sl = yt.SlicePlot(ds, 2, ('boxlib', 'ux'))
sl.set_log(('ux'), False)
sl.set_zlim(('ux'), -0.01, 0.01)
# ds.find_min("ux")
sl
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 ds = AMReXDataset("plt00300")
#       2 sl = yt.SlicePlot(ds, 2, ('boxlib', 'ux'))
#       3 sl.set_log(('ux'), False)
#
# File ~/.local/lib/python3.10/site-packages/yt/frontends/amrex/data_structures.py:660, in BoxlibDataset.__init__(self, output_dir, cparam_filename, fparam_filename, dataset_type, storage_filename, units_override, unit_system, default_species_fields)
#     657 self.fparam_filename = self._localize_check(fparam_filename)
#     658 self.storage_filename = storage_filename
# --> 660 Dataset.__init__(
#     661     self,
#     662     output_dir,
#     663     dataset_type,
#     664     units_override=units_override,
#     665     unit_system=unit_system,
#     666     default_species_fields=default_species_fields,
#     667 )
#     669 # These are still used in a few places.
#     670 if "HydroMethod" not in self.parameters.keys():
#
# File ~/.local/lib/python3.10/site-packages/yt/data_objects/static_output.py:291, in Dataset.__init__(self, filename, dataset_type, units_override, unit_system, default_species_fields, axis_order)
#     287     used_unit_system = unit_system
#     289 self._create_unit_registry(used_unit_system)
# --> 291 self._parse_parameter_file()
#     292 self.set_units()
#     293 self.setup_cosmology()
#
# File ~/.local/lib/python3.10/site-packages/yt/frontends/amrex/data_structures.py:955, in AMReXDataset._parse_parameter_file(self)
#     954 def _parse_parameter_file(self):
# --> 955     super()._parse_parameter_file()
#     956     particle_types = glob.glob(os.path.join(self.output_dir, "*", "Header"))
#     957     particle_types = [cpt.split(os.sep)[-2] for cpt in particle_types]
#
# File ~/.local/lib/python3.10/site-packages/yt/frontends/amrex/data_structures.py:734, in BoxlibDataset._parse_parameter_file(self)
#     729 """
#     730 Parses the parameter file and establishes the various
#     731 dictionaries.
#     732 """
#     733 self._periodicity = (False, False, False)
# --> 734 self._parse_header_file()
#     735 # Let's read the file
#     736 # the 'inputs' file is now optional
#     737 self._parse_cparams()
#
# File ~/.local/lib/python3.10/site-packages/yt/frontends/amrex/data_structures.py:824, in BoxlibDataset._parse_header_file(self)
#     813 """
#     814 We parse the Boxlib header, which we use as our basis.  Anything in the
#     815 inputs file will override this, but the inputs file is not strictly
#     816 necessary for orientation of the data in space.
#     817 """
#     819 # Note: Python uses a read-ahead buffer, so using next(), which would
#     820 # be my preferred solution, won't work here.  We have to explicitly
#     821 # call readline() if we want to end up with an offset at the very end.
#     822 # Fortunately, elsewhere we don't care about the offset, so we're fine
#     823 # everywhere else using iteration exclusively.
# --> 824 header_file = open(os.path.join(self.output_dir, "Header"))
#     825 self.orion_version = header_file.readline().rstrip()
#     826 n_fields = int(header_file.readline())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/haotian/Dropbox/Research/lattice_boltzmann_method/AMREX_LBM/plt00300/Header'

# %% [markdown]
# ## Validation of the results using analytical solution

# %%
import numpy as np
import matplotlib.pyplot as plt
L=64
u_max=0.02
rho0=1
kx=2*np.pi/L
ky=2*np.pi/L
nu=1/6
td= td = 1.0 / (nu * (kx * kx + ky * ky))

xxx=np.linspace(0,L-1,L)+.5
yyy=np.linspace(0,L-1,L)+.5
xmesh,ymesh = np.meshgrid(xxx,yyy,indexing='ij')
xmesh = xmesh.flatten()
ymesh = ymesh.flatten()
time_list=[]
error_ux_list=[]
error_uy_list=[]
error_rho_list=[]
for time in range(0,850,50):
    ux_analytic = -u_max*np.sqrt(ky/kx)*np.cos(kx*xmesh)*np.sin(ky*ymesh)*np.exp(-1.0*time/td)
    uy_analytic = u_max*np.sqrt(kx/ky)*np.sin(kx*xmesh)*np.cos(ky*ymesh)*np.exp(-1.0*time/td)
    P_analytic = -0.25 * rho0 * u_max * u_max * ((ky / kx) * np.cos(2.0 * kx * xmesh) + (kx / ky) * np.cos(2.0 * ky * ymesh)) * np.exp(-2.0 * time / td)
    rho_analytic = rho0 + 3.0 * P_analytic
    
    ds = AMReXDataset( f"plt{time:05}")
    rho_numerical=ds.all_data()[('boxlib', 'rho')].to_ndarray()
    ux_numerical=ds.all_data()[('boxlib', 'ux')].to_ndarray()
    uy_numerical=ds.all_data()[('boxlib', 'uy')].to_ndarray()
    
    error_ux=np.sqrt(np.mean(np.square(ux_analytic-ux_numerical))/np.mean(np.square(ux_analytic)))
    error_uy=np.sqrt(np.mean(np.square(uy_analytic-uy_numerical))/np.mean(np.square(uy_analytic)))
    error_rho=np.sqrt(np.mean(np.square(rho_analytic-rho_numerical))/np.mean(np.square(rho_analytic-rho0)))
    
    print(f"Time: {time}, Error in ux: {error_ux}, Error in uy: {error_uy}, Error in rho: {error_rho}") 
    time_list.append(time)
    error_ux_list.append(error_ux)
    error_uy_list.append(error_uy)
    error_rho_list.append(error_rho)

plt.plot(time_list,error_ux_list,label='Error in ux')
plt.plot(time_list,error_uy_list,label='Error in uy')
plt.plot(time_list,error_rho_list,label='Error in rho')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Error')
plt.show()
# Out:
# yt : [INFO     ] 2024-12-06 11:54:32,350 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-12-06 11:54:32,351 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:32,352 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:32,352 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:32,521 Parameters: current_time              = 50.0
# yt : [INFO     ] 2024-12-06 11:54:32,521 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:32,522 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:32,523 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:32,680 Parameters: current_time              = 100.0
# yt : [INFO     ] 2024-12-06 11:54:32,681 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:32,682 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:32,683 Parameters: domain_right_edge         = [64. 64.  1.]
# Time: 0, Error in ux: 0.0, Error in uy: 0.0, Error in rho: 0.0
# Time: 50, Error in ux: 0.00021702932031927695, Error in uy: 0.00021702932031924027, Error in rho: 0.031770306923663144
# yt : [INFO     ] 2024-12-06 11:54:32,876 Parameters: current_time              = 150.0
# yt : [INFO     ] 2024-12-06 11:54:32,877 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:32,878 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:32,879 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:33,040 Parameters: current_time              = 200.0
# Time: 100, Error in ux: 0.000428805576928392, Error in uy: 0.00042880557693013326, Error in rho: 0.04949328364089297
# Time: 150, Error in ux: 0.0006517905706259755, Error in uy: 0.000651790570624497, Error in rho: 0.0467914207767364
# yt : [INFO     ] 2024-12-06 11:54:33,041 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:33,042 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:33,043 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:33,202 Parameters: current_time              = 250.0
# yt : [INFO     ] 2024-12-06 11:54:33,203 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:33,204 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:33,205 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:33,365 Parameters: current_time              = 300.0
# yt : [INFO     ] 2024-12-06 11:54:33,366 Parameters: domain_dimensions         = [64 64  1]
# Time: 200, Error in ux: 0.0007839361275741638, Error in uy: 0.0007839361275737752, Error in rho: 0.02538677638303371
# Time: 250, Error in ux: 0.0008200229763814605, Error in uy: 0.0008200229763792979, Error in rho: 0.008339983883057215
# yt : [INFO     ] 2024-12-06 11:54:33,367 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:33,368 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:33,529 Parameters: current_time              = 350.0
# yt : [INFO     ] 2024-12-06 11:54:33,530 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:33,531 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:33,531 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:33,691 Parameters: current_time              = 400.0
# yt : [INFO     ] 2024-12-06 11:54:33,692 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:33,692 Parameters: domain_left_edge          = [0. 0. 0.]
# Time: 300, Error in ux: 0.0008124192286437939, Error in uy: 0.0008124192286439388, Error in rho: 0.03949202418036365
# Time: 350, Error in ux: 0.000831746894645212, Error in uy: 0.00083174689464548, Error in rho: 0.05882915238246072
# yt : [INFO     ] 2024-12-06 11:54:33,694 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:34,018 Parameters: current_time              = 450.0
# yt : [INFO     ] 2024-12-06 11:54:34,019 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:34,019 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:34,020 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:34,178 Parameters: current_time              = 500.0
# yt : [INFO     ] 2024-12-06 11:54:34,179 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:34,180 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:34,181 Parameters: domain_right_edge         = [64. 64.  1.]
# Time: 400, Error in ux: 0.0009084852337970597, Error in uy: 0.0009084852337971086, Error in rho: 0.05872203634433493
# Time: 450, Error in ux: 0.0010226033945014688, Error in uy: 0.0010226033945041975, Error in rho: 0.03911220274575234
# yt : [INFO     ] 2024-12-06 11:54:34,340 Parameters: current_time              = 550.0
# yt : [INFO     ] 2024-12-06 11:54:34,341 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:34,341 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:34,342 Parameters: domain_right_edge         = [64. 64.  1.]
# Time: 500, Error in ux: 0.001148091599806148, Error in uy: 0.0011480915998039382, Error in rho: 0.007521964300587539
# Time: 550, Error in ux: 0.001275339691759365, Error in uy: 0.0012753396917563821, Error in rho: 0.026427071416291092
# yt : [INFO     ] 2024-12-06 11:54:34,519 Parameters: current_time              = 600.0
# yt : [INFO     ] 2024-12-06 11:54:34,521 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:34,522 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:34,523 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:34,710 Parameters: current_time              = 650.0
# yt : [INFO     ] 2024-12-06 11:54:34,711 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:34,711 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:34,712 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:34,872 Parameters: current_time              = 700.0
# yt : [INFO     ] 2024-12-06 11:54:34,873 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:34,874 Parameters: domain_left_edge          = [0. 0. 0.]
# Time: 600, Error in ux: 0.0014041729570938297, Error in uy: 0.0014041729571036118, Error in rho: 0.048396492135965016
# Time: 650, Error in ux: 0.0015344067583806613, Error in uy: 0.001534406758367868, Error in rho: 0.05155218371884267
# yt : [INFO     ] 2024-12-06 11:54:34,875 Parameters: domain_right_edge         = [64. 64.  1.]
# yt : [INFO     ] 2024-12-06 11:54:35,042 Parameters: current_time              = 750.0
# yt : [INFO     ] 2024-12-06 11:54:35,042 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:35,043 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:35,044 Parameters: domain_right_edge         = [64. 64.  1.]
# Time: 700, Error in ux: 0.001664198926692354, Error in uy: 0.0016641989267073003, Error in rho: 0.03485980543723271
# Time: 750, Error in ux: 0.0017923732764706642, Error in uy: 0.0017923732764717171, Error in rho: 0.005345234268641567
# yt : [INFO     ] 2024-12-06 11:54:35,223 Parameters: current_time              = 800.0
# yt : [INFO     ] 2024-12-06 11:54:35,225 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2024-12-06 11:54:35,226 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-12-06 11:54:35,227 Parameters: domain_right_edge         = [64. 64.  1.]
# Time: 800, Error in ux: 0.0019194569784672395, Error in uy: 0.0019194569784600117, Error in rho: 0.02885290668509941

# %%
# read all lines in file "out" and put in a list
# read all lines in file "out2" and put in a list
# find the lines in out2 but not in out
# print those lines
# examine what lines have appeared twice in out2

with open("out") as f:
    out = f.readlines()
with open("out2") as f:
    out2 = f.readlines()
with open("out3") as f:
    out3 = f.readlines()
print("in out2 but not in out")
for line in out2:
    if line not in out:
        print(line)
print("in out but not in out3")  
for line in out:
    if line not in out3:
        print(line)
print("appearing twice in out2")
from collections import Counter
c = Counter(out2)
for line in out2:
    if c[line] > 1:
        print(line)
# Out:
# in out2 but not in out
# max_grid_size: 16
#
# in out but not in out3
# Initializing AMReX (24.11-23-g456c93c7d951)...
#
# AMReX (24.11-23-g456c93c7d951) initialized
#
# max_grid_size: 32
#
# 1	-1	-1	30	31
#
# 1	0	-1	31	31
#
# 1	1	-1	0	31
#
# 1	2	-1	1	31
#
# 1	3	-1	2	31
#
# 1	4	-1	3	31
#
# 1	5	-1	4	31
#
# 1	6	-1	5	31
#
# 1	7	-1	6	31
#
# 1	8	-1	7	31
#
# 1	9	-1	8	31
#
# 1	10	-1	9	31
#
# 1	11	-1	10	31
#
# 1	12	-1	11	31
#
# 1	13	-1	12	31
#
# 1	14	-1	13	31
#
# 1	15	-1	14	31
#
# 1	16	-1	15	31
#
# 1	17	-1	16	31
#
# 1	18	-1	17	31
#
# 1	19	-1	18	31
#
# 1	20	-1	19	31
#
# 1	21	-1	20	31
#
# 1	22	-1	21	31
#
# 1	23	-1	22	31
#
# 1	24	-1	23	31
#
# 1	25	-1	24	31
#
# 1	26	-1	25	31
#
# 1	27	-1	26	31
#
# 1	28	-1	27	31
#
# 1	29	-1	28	31
#
# 1	30	-1	29	31
#
# 1	31	-1	30	31
#
# 1	32	-1	31	31
#
# 1	-1	0	30	0
#
# 1	32	0	31	0
#
# 1	-1	1	30	1
#
# 1	32	1	31	1
#
# 1	-1	2	30	2
#
# 1	32	2	31	2
#
# 1	-1	3	30	3
#
# 1	32	3	31	3
#
# 1	-1	4	30	4
#
# 1	32	4	31	4
#
# 1	-1	5	30	5
#
# 1	32	5	31	5
#
# 1	-1	6	30	6
#
# 1	32	6	31	6
#
# 1	-1	7	30	7
#
# 1	32	7	31	7
#
# 1	-1	8	30	8
#
# 1	32	8	31	8
#
# 1	-1	9	30	9
#
# 1	32	9	31	9
#
# 1	-1	10	30	10
#
# 1	32	10	31	10
#
# 1	-1	11	30	11
#
# 1	32	11	31	11
#
# 1	-1	12	30	12
#
# 1	32	12	31	12
#
# 1	-1	13	30	13
#
# 1	32	13	31	13
#
# 1	-1	14	30	14
#
# 1	32	14	31	14
#
# 1	-1	15	30	15
#
# 1	32	15	31	15
#
# 1	-1	16	30	16
#
# 1	32	16	31	16
#
# 1	-1	17	30	17
#
# 1	32	17	31	17
#
# 1	-1	18	30	18
#
# 1	32	18	31	18
#
# 1	-1	19	30	19
#
# 1	32	19	31	19
#
# 1	-1	20	30	20
#
# 1	32	20	31	20
#
# 1	-1	21	30	21
#
# 1	32	21	31	21
#
# 1	-1	22	30	22
#
# 1	32	22	31	22
#
# 1	-1	23	30	23
#
# 1	32	23	31	23
#
# 1	-1	24	30	24
#
# 1	32	24	31	24
#
# 1	-1	25	30	25
#
# 1	32	25	31	25
#
# 1	-1	26	30	26
#
# 1	32	26	31	26
#
# 1	-1	27	30	27
#
# 1	32	27	31	27
#
# 1	-1	28	30	28
#
# 1	32	28	31	28
#
# 1	-1	29	30	29
#
# 1	32	29	31	29
#
# 1	-1	30	30	30
#
# 1	32	30	31	30
#
# 1	-1	31	30	31
#
# 1	32	31	31	31
#
# 1	-1	32	30	0
#
# 1	0	32	31	0
#
# 1	1	32	0	0
#
# 1	2	32	1	0
#
# 1	3	32	2	0
#
# 1	4	32	3	0
#
# 1	5	32	4	0
#
# 1	6	32	5	0
#
# 1	7	32	6	0
#
# 1	8	32	7	0
#
# 1	9	32	8	0
#
# 1	10	32	9	0
#
# 1	11	32	10	0
#
# 1	12	32	11	0
#
# 1	13	32	12	0
#
# 1	14	32	13	0
#
# 1	15	32	14	0
#
# 1	16	32	15	0
#
# 1	17	32	16	0
#
# 1	18	32	17	0
#
# 1	19	32	18	0
#
# 1	20	32	19	0
#
# 1	21	32	20	0
#
# 1	22	32	21	0
#
# 1	23	32	22	0
#
# 1	24	32	23	0
#
# 1	25	32	24	0
#
# 1	26	32	25	0
#
# 1	27	32	26	0
#
# 1	28	32	27	0
#
# 1	29	32	28	0
#
# 1	30	32	29	0
#
# 1	31	32	30	0
#
# 1	32	32	31	0
#
# AMReX (24.11-23-g456c93c7d951) finalized
#
# appearing twice in out2
# 1	15	-1	14	31
#
# 1	16	-1	15	31
#
# 1	15	0	14	0
#
# 1	16	0	15	0
#
# 1	15	1	14	1
#
# 1	16	1	15	1
#
# 1	15	2	14	2
#
# 1	16	2	15	2
#
# 1	15	3	14	3
#
# 1	16	3	15	3
#
# 1	15	4	14	4
#
# 1	16	4	15	4
#
# 1	15	5	14	5
#
# 1	16	5	15	5
#
# 1	15	6	14	6
#
# 1	16	6	15	6
#
# 1	15	7	14	7
#
# 1	16	7	15	7
#
# 1	15	8	14	8
#
# 1	16	8	15	8
#
# 1	15	9	14	9
#
# 1	16	9	15	9
#
# 1	15	10	14	10
#
# 1	16	10	15	10
#
# 1	15	11	14	11
#
# 1	16	11	15	11
#
# 1	15	12	14	12
#
# 1	16	12	15	12
#
# 1	15	13	14	13
#
# 1	16	13	15	13
#
# 1	15	14	14	14
#
# 1	16	14	15	14
#
# 1	-1	15	30	15
#
# 1	0	15	31	15
#
# 1	1	15	0	15
#
# 1	2	15	1	15
#
# 1	3	15	2	15
#
# 1	4	15	3	15
#
# 1	5	15	4	15
#
# 1	6	15	5	15
#
# 1	7	15	6	15
#
# 1	8	15	7	15
#
# 1	9	15	8	15
#
# 1	10	15	9	15
#
# 1	11	15	10	15
#
# 1	12	15	11	15
#
# 1	13	15	12	15
#
# 1	14	15	13	15
#
# 1	15	15	14	15
#
# 1	16	15	15	15
#
# 1	-1	16	30	16
#
# 1	0	16	31	16
#
# 1	1	16	0	16
#
# 1	2	16	1	16
#
# 1	3	16	2	16
#
# 1	4	16	3	16
#
# 1	5	16	4	16
#
# 1	6	16	5	16
#
# 1	7	16	6	16
#
# 1	8	16	7	16
#
# 1	9	16	8	16
#
# 1	10	16	9	16
#
# 1	11	16	10	16
#
# 1	12	16	11	16
#
# 1	13	16	12	16
#
# 1	14	16	13	16
#
# 1	15	16	14	16
#
# 1	16	16	15	16
#
# 1	15	-1	14	31
#
# 1	16	-1	15	31
#
# 1	15	0	14	0
#
# 1	16	0	15	0
#
# 1	15	1	14	1
#
# 1	16	1	15	1
#
# 1	15	2	14	2
#
# 1	16	2	15	2
#
# 1	15	3	14	3
#
# 1	16	3	15	3
#
# 1	15	4	14	4
#
# 1	16	4	15	4
#
# 1	15	5	14	5
#
# 1	16	5	15	5
#
# 1	15	6	14	6
#
# 1	16	6	15	6
#
# 1	15	7	14	7
#
# 1	16	7	15	7
#
# 1	15	8	14	8
#
# 1	16	8	15	8
#
# 1	15	9	14	9
#
# 1	16	9	15	9
#
# 1	15	10	14	10
#
# 1	16	10	15	10
#
# 1	15	11	14	11
#
# 1	16	11	15	11
#
# 1	15	12	14	12
#
# 1	16	12	15	12
#
# 1	15	13	14	13
#
# 1	16	13	15	13
#
# 1	15	14	14	14
#
# 1	16	14	15	14
#
# 1	15	15	14	15
#
# 1	16	15	15	15
#
# 1	17	15	16	15
#
# 1	18	15	17	15
#
# 1	19	15	18	15
#
# 1	20	15	19	15
#
# 1	21	15	20	15
#
# 1	22	15	21	15
#
# 1	23	15	22	15
#
# 1	24	15	23	15
#
# 1	25	15	24	15
#
# 1	26	15	25	15
#
# 1	27	15	26	15
#
# 1	28	15	27	15
#
# 1	29	15	28	15
#
# 1	30	15	29	15
#
# 1	31	15	30	15
#
# 1	32	15	31	15
#
# 1	15	16	14	16
#
# 1	16	16	15	16
#
# 1	17	16	16	16
#
# 1	18	16	17	16
#
# 1	19	16	18	16
#
# 1	20	16	19	16
#
# 1	21	16	20	16
#
# 1	22	16	21	16
#
# 1	23	16	22	16
#
# 1	24	16	23	16
#
# 1	25	16	24	16
#
# 1	26	16	25	16
#
# 1	27	16	26	16
#
# 1	28	16	27	16
#
# 1	29	16	28	16
#
# 1	30	16	29	16
#
# 1	31	16	30	16
#
# 1	32	16	31	16
#
# 1	-1	15	30	15
#
# 1	0	15	31	15
#
# 1	1	15	0	15
#
# 1	2	15	1	15
#
# 1	3	15	2	15
#
# 1	4	15	3	15
#
# 1	5	15	4	15
#
# 1	6	15	5	15
#
# 1	7	15	6	15
#
# 1	8	15	7	15
#
# 1	9	15	8	15
#
# 1	10	15	9	15
#
# 1	11	15	10	15
#
# 1	12	15	11	15
#
# 1	13	15	12	15
#
# 1	14	15	13	15
#
# 1	15	15	14	15
#
# 1	16	15	15	15
#
# 1	-1	16	30	16
#
# 1	0	16	31	16
#
# 1	1	16	0	16
#
# 1	2	16	1	16
#
# 1	3	16	2	16
#
# 1	4	16	3	16
#
# 1	5	16	4	16
#
# 1	6	16	5	16
#
# 1	7	16	6	16
#
# 1	8	16	7	16
#
# 1	9	16	8	16
#
# 1	10	16	9	16
#
# 1	11	16	10	16
#
# 1	12	16	11	16
#
# 1	13	16	12	16
#
# 1	14	16	13	16
#
# 1	15	16	14	16
#
# 1	16	16	15	16
#
# 1	15	17	14	17
#
# 1	16	17	15	17
#
# 1	15	18	14	18
#
# 1	16	18	15	18
#
# 1	15	19	14	19
#
# 1	16	19	15	19
#
# 1	15	20	14	20
#
# 1	16	20	15	20
#
# 1	15	21	14	21
#
# 1	16	21	15	21
#
# 1	15	22	14	22
#
# 1	16	22	15	22
#
# 1	15	23	14	23
#
# 1	16	23	15	23
#
# 1	15	24	14	24
#
# 1	16	24	15	24
#
# 1	15	25	14	25
#
# 1	16	25	15	25
#
# 1	15	26	14	26
#
# 1	16	26	15	26
#
# 1	15	27	14	27
#
# 1	16	27	15	27
#
# 1	15	28	14	28
#
# 1	16	28	15	28
#
# 1	15	29	14	29
#
# 1	16	29	15	29
#
# 1	15	30	14	30
#
# 1	16	30	15	30
#
# 1	15	31	14	31
#
# 1	16	31	15	31
#
# 1	15	32	14	0
#
# 1	16	32	15	0
#
# 1	15	15	14	15
#
# 1	16	15	15	15
#
# 1	17	15	16	15
#
# 1	18	15	17	15
#
# 1	19	15	18	15
#
# 1	20	15	19	15
#
# 1	21	15	20	15
#
# 1	22	15	21	15
#
# 1	23	15	22	15
#
# 1	24	15	23	15
#
# 1	25	15	24	15
#
# 1	26	15	25	15
#
# 1	27	15	26	15
#
# 1	28	15	27	15
#
# 1	29	15	28	15
#
# 1	30	15	29	15
#
# 1	31	15	30	15
#
# 1	32	15	31	15
#
# 1	15	16	14	16
#
# 1	16	16	15	16
#
# 1	17	16	16	16
#
# 1	18	16	17	16
#
# 1	19	16	18	16
#
# 1	20	16	19	16
#
# 1	21	16	20	16
#
# 1	22	16	21	16
#
# 1	23	16	22	16
#
# 1	24	16	23	16
#
# 1	25	16	24	16
#
# 1	26	16	25	16
#
# 1	27	16	26	16
#
# 1	28	16	27	16
#
# 1	29	16	28	16
#
# 1	30	16	29	16
#
# 1	31	16	30	16
#
# 1	32	16	31	16
#
# 1	15	17	14	17
#
# 1	16	17	15	17
#
# 1	15	18	14	18
#
# 1	16	18	15	18
#
# 1	15	19	14	19
#
# 1	16	19	15	19
#
# 1	15	20	14	20
#
# 1	16	20	15	20
#
# 1	15	21	14	21
#
# 1	16	21	15	21
#
# 1	15	22	14	22
#
# 1	16	22	15	22
#
# 1	15	23	14	23
#
# 1	16	23	15	23
#
# 1	15	24	14	24
#
# 1	16	24	15	24
#
# 1	15	25	14	25
#
# 1	16	25	15	25
#
# 1	15	26	14	26
#
# 1	16	26	15	26
#
# 1	15	27	14	27
#
# 1	16	27	15	27
#
# 1	15	28	14	28
#
# 1	16	28	15	28
#
# 1	15	29	14	29
#
# 1	16	29	15	29
#
# 1	15	30	14	30
#
# 1	16	30	15	30
#
# 1	15	31	14	31
#
# 1	16	31	15	31
#
# 1	15	32	14	0
#
# 1	16	32	15	0
